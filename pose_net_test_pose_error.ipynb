# %%
import os
import torch
import cv2
import cPickle
import numpy as np

from faster_rcnn import network
from faster_rcnn.faster_rcnn import FasterRCNN, RPN
from faster_rcnn.utils.timer import Timer
from faster_rcnn.fast_rcnn.nms_wrapper import nms

from faster_rcnn.fast_rcnn.bbox_transform import bbox_transform_inv, clip_boxes
from faster_rcnn.datasets.factory import get_imdb
from faster_rcnn.fast_rcnn.config import cfg, cfg_from_file, get_output_dir

from faster_rcnn.pose_net import PoseNet

from matplotlib import pyplot as plt
# %matplotlib inline
import matplotlib as mpl
mpl.rcParams['figure.dpi']= 300


# hyper-parameters
# ------------
#imdb_name = 'voc_2007_test'
#imdb_name = 'kittivoc_train'
#imdb_name = 'kittivoc_val'
imdb_name = 'kittipose_val'
#imdb_name = 'kitti_train'
cfg_file = 'experiments/cfgs/faster_rcnn_end2end.yml'
# trained_model = 'models/saved_model9/faster_rcnn_100000.h5'
trained_model = 'models/saved_pose_model_final/faster_rcnn_80000.h5'

# rand_seed = 1024

save_name = 'faster_rcnn_100000'
max_per_image = 300
thresh = 0.05
vis = True

# ------------

# load config
cfg_from_file(cfg_file)

# %%
# load data
imdb = get_imdb(imdb_name)
imdb.competition_mode(on=True)
# Out:
# <bound method kittipose.default_roidb of <faster_rcnn.datasets.kittipose.kittipose object at 0x7f9d14529a90>>
# Remove empty annotations:  Done.

# %%
# load net
net = PoseNet(classes=imdb.classes, debug=False)
# network.load_net(trained_model, net.frcnn) # only load frcnn weights
network.load_net(trained_model, net)
print('load model successfully!')

net.cuda()
net.eval(); # set network to evaluation mode, which affects the behavior of batch norm, dropout, etc
# Out:
# load model successfully!

# %%
pose_errors_all = [] # these are relative error
silent = True

def vis_detections(im, class_name, dets, poses, all_poses, thresh=0.8):
    """Visual debugging of detections."""
    for i in range(np.minimum(10, dets.shape[0])):
        bbox = tuple(int(np.round(x)) for x in dets[i, :4])
        score = dets[i, -1]
        if score > thresh:
            cv2.rectangle(im, bbox[0:2], bbox[2:4], (0, 204, 0), 2)
            cv2.putText(im, '%s: %.3f' % (class_name, score), (bbox[0], bbox[1] + 15), cv2.FONT_HERSHEY_PLAIN,
                        1.0, (0, 0, 255), thickness=1)
            poses[i] = poses[i] / np.array(cfg.POSE_INV_VARS) + np.array(cfg.POSE_MEANS)
            if not silent:
                print class_name, i, "pose:"
                print ["{0:0.2f}".format(p) for p in poses[i]]
            # append pose error to pose_erros_all
            if len(all_poses) == 0 or poses.shape[0] > len(all_poses):
                continue
            min_err = None
            min_dist = 100000
            for label in all_poses:
                dist = 0
                err = []
                for k in range(len(label)):
                    dist += abs(poses[i,k]-label[k])/(abs(label[k])+2e-1) # relative error
                    err.append(  abs(poses[i,k]-label[k])/(abs(label[k])+2e-1)  )
                if dist < min_dist:
                    min_dist = dist
                    min_err = err
            pose_errors_all.append(min_err)
    return im


def im_detect(net, image, disparity):
    """Detect object classes in an image given object proposals.
    Returns:
        scores (ndarray): R x K array of object class scores (K includes
            background as object category 0)
        boxes (ndarray): R x (4*K) array of predicted bounding boxes
    """
    # image.shape = H x W x 3
    # im_data, im_scales = net.get_image_blob(image)
    im_data, im_scales, disp_data = net.frcnn.get_image_disparity_blob(image, disparity)
    # get_image_blob() tries to make H = 600 but keep W <= 1000
    # image gets resized, and the resize scale is returned
    # im_data: 1 x H x W x 3
    # im_scales: array with one number

    im_info = np.array(
        [[im_data.shape[1], im_data.shape[2], im_scales[0]]],
        dtype=np.float32)

    cls_prob, bbox_pred, rois, pose_pred = net(im_data, im_info, disp_data)
    # cls_prob.shape = (300, 4) # KITTI has four classes, '__background__', 'Car', 'Pedestrian', 'Cyclist'
    # bbox_pred.shape = (300, 16)
    # rois.shape = (300, 5)
    
    scores = cls_prob.data.cpu().numpy()
    boxes = rois.data.cpu().numpy()[:, 1:5] / im_info[0][2]
    poses = pose_pred.data.cpu().numpy() # convert pose prediction from torch to numpy
    cfg.TEST.BBOX_REG = True
    if cfg.TEST.BBOX_REG: # True in this case
        # Apply bounding-box regression deltas
        box_deltas = bbox_pred.data.cpu().numpy()
        pred_boxes = bbox_transform_inv(boxes, box_deltas)
        pred_boxes = clip_boxes(pred_boxes, image.shape)
        # pred_boxes.shape = (300, 16)
    else:
        # Simply repeat the boxes, once for each class
        pred_boxes = np.tile(boxes, (1, scores.shape[1]))

    return scores, pred_boxes, poses

# %%
max_per_image=300
thresh=0.05
# idx_image = 6 # the idx of the image that we want to test
num_images = len(imdb.image_index)
idx_image = np.random.randint(0, num_images, 1)[0]


# all detections are collected into:
#    all_boxes[cls][image] = N x 5 array of detections in
#    (x1, y1, x2, y2, score)
all_boxes = [[[] for _ in xrange(num_images)]
             for _ in xrange(imdb.num_classes)]


# timers
_t = {'im_detect': Timer(), 'misc': Timer()}

print "# of images: ", num_images

# for i in range(100):
for i in range(num_images):
# for i in range(idx_image,idx_image+1):
    im_path = imdb.image_path_at(i)
    folder = im_path[0:-10]
    img_name = im_path[-10:-3]
    img_name += 'png'
    disp_path = folder + 'disparity/' + img_name # path to disparity map
    
    im = cv2.imread(im_path)
    disp = cv2.imread(disp_path)
    
    # print out the groundtruth label
    img_index = im_path[-10:-4]
    label_path = "/media/data/kitti_dataset/2d_object/data_object_image_2/training/label_2/" + img_index + ".txt"
    if not silent:
        print "\n"
        print "Groundtruth labels:"
        f = open(label_path, 'r')
        print(f.read())
        f.close()
    # extract labels
    f = open(label_path, 'r')
    line = f.readline()
    all_poses = []
    while line:
        info = line.split()
        line = f.readline()
        if info[0] not in ["Car", "Cyclist", "Pedestrian"]:
            # print info[0]
            continue
        pose = info[-7:]
        pose = [float(p) for p in pose]
        all_poses.append(pose)
    f.close()
    
    _t['im_detect'].tic()
    
    scores, boxes, poses = im_detect(net, im, disp_path)
    # scores.shape = (300, 4)
    # boxes.shape = (300, 16)
    
    detect_time = _t['im_detect'].toc(average=False)

    
    if vis:
        # im2show = np.copy(im[:, :, (2, 1, 0)])
        im2show = np.copy(im)

    # skip j = 0, because it's the background class
    for j in xrange(1, imdb.num_classes):
        inds = np.where(scores[:, j] > thresh)[0]
        cls_scores = scores[inds, j]
        cls_boxes = boxes[inds, j * 4:(j + 1) * 4]
        cls_dets = np.hstack((cls_boxes, cls_scores[:, np.newaxis])) \
            .astype(np.float32, copy=False)
        keep = nms(cls_dets, cfg.TEST.NMS)
        cls_dets = cls_dets[keep, :]
        poses_keep = poses[keep, :]
        
        if vis:
            im2show = vis_detections(im2show, imdb.classes[j], cls_dets, poses_keep, all_poses)
        all_boxes[j][i] = cls_dets

    # Limit to max_per_image detections *over all classes*
    _t['misc'].tic()
    if max_per_image > 0:
        image_scores = np.hstack([all_boxes[j][i][:, -1]
                                  for j in xrange(1, imdb.num_classes)])
        if len(image_scores) > max_per_image:
            image_thresh = np.sort(image_scores)[-max_per_image]
            for j in xrange(1, imdb.num_classes):
                keep = np.where(all_boxes[j][i][:, -1] >= image_thresh)[0]
                all_boxes[j][i] = all_boxes[j][i][keep, :]
    nms_time = _t['misc'].toc(average=False)

    print 'im_detect: {:d}/{:d} {:.3f}s {:.3f}s' \
        .format(i + 1, num_images, detect_time, nms_time)

    if vis and not silent:
        #cv2.imshow('test', im2show)
        #cv2.waitKey(0)
        plt.imshow(im2show)
        #pass
# Out:
# # of images:  1480
# im_detect: 1/1480 0.106s 0.000s
# im_detect: 2/1480 0.100s 0.000s
# im_detect: 3/1480 0.097s 0.000s
# im_detect: 4/1480 0.095s 0.000s
# im_detect: 5/1480 0.096s 0.000s
# im_detect: 6/1480 0.096s 0.000s
# im_detect: 7/1480 0.097s 0.000s
# im_detect: 8/1480 0.094s 0.000s
# im_detect: 9/1480 0.095s 0.000s
# im_detect: 10/1480 0.092s 0.000s
# im_detect: 11/1480 0.092s 0.000s
# im_detect: 12/1480 0.094s 0.000s
# im_detect: 13/1480 0.096s 0.000s
# im_detect: 14/1480 0.093s 0.000s
# im_detect: 15/1480 0.102s 0.000s
# im_detect: 16/1480 0.101s 0.000s
# im_detect: 17/1480 0.100s 0.000s
# im_detect: 18/1480 0.098s 0.000s
# im_detect: 19/1480 0.095s 0.000s
# im_detect: 20/1480 0.098s 0.000s
# im_detect: 21/1480 0.099s 0.000s
# im_detect: 22/1480 0.099s 0.000s
# im_detect: 23/1480 0.100s 0.000s
# im_detect: 24/1480 0.109s 0.000s
# im_detect: 25/1480 0.100s 0.000s
# im_detect: 26/1480 0.097s 0.000s
# im_detect: 27/1480 0.094s 0.000s
# im_detect: 28/1480 0.098s 0.000s
# im_detect: 29/1480 0.106s 0.000s
# im_detect: 30/1480 0.102s 0.000s
# im_detect: 31/1480 0.097s 0.000s
# im_detect: 32/1480 0.096s 0.000s
# im_detect: 33/1480 0.096s 0.000s
# im_detect: 34/1480 0.096s 0.000s
# im_detect: 35/1480 0.098s 0.000s
# im_detect: 36/1480 0.097s 0.000s
# im_detect: 37/1480 0.093s 0.000s
# im_detect: 38/1480 0.095s 0.000s
# im_detect: 39/1480 0.092s 0.000s
# im_detect: 40/1480 0.093s 0.000s
# im_detect: 41/1480 0.093s 0.000s
# im_detect: 42/1480 0.097s 0.000s
# im_detect: 43/1480 0.096s 0.000s
# im_detect: 1423/1480 0.096s 0.000s
# im_detect: 1424/1480 0.097s 0.000s
# im_detect: 1425/1480 0.093s 0.000s
# im_detect: 1426/1480 0.092s 0.000s
# im_detect: 1427/1480 0.093s 0.000s
# im_detect: 1428/1480 0.091s 0.000s
# im_detect: 1429/1480 0.097s 0.000s
# im_detect: 1430/1480 0.097s 0.000s
# im_detect: 1431/1480 0.099s 0.000s
# im_detect: 1432/1480 0.092s 0.000s
# im_detect: 1433/1480 0.094s 0.000s
# im_detect: 1434/1480 0.094s 0.000s
# im_detect: 1435/1480 0.095s 0.000s
# im_detect: 1436/1480 0.094s 0.000s
# im_detect: 1437/1480 0.097s 0.000s
# im_detect: 1438/1480 0.104s 0.000s
# im_detect: 1439/1480 0.097s 0.000s
# im_detect: 1440/1480 0.090s 0.000s
# im_detect: 1441/1480 0.093s 0.000s
# im_detect: 1442/1480 0.093s 0.000s
# im_detect: 1443/1480 0.096s 0.000s
# im_detect: 1444/1480 0.095s 0.000s
# im_detect: 1445/1480 0.097s 0.000s
# im_detect: 1446/1480 0.094s 0.000s
# im_detect: 1447/1480 0.092s 0.000s
# im_detect: 1448/1480 0.095s 0.000s
# im_detect: 1449/1480 0.093s 0.000s
# im_detect: 1450/1480 0.099s 0.000s
# im_detect: 1451/1480 0.097s 0.000s
# im_detect: 1452/1480 0.096s 0.000s
# im_detect: 1453/1480 0.094s 0.000s
# im_detect: 1454/1480 0.096s 0.000s
# im_detect: 1455/1480 0.095s 0.000s
# im_detect: 1456/1480 0.094s 0.000s
# im_detect: 1457/1480 0.096s 0.000s
# im_detect: 1458/1480 0.093s 0.000s
# im_detect: 1459/1480 0.092s 0.000s
# im_detect: 1460/1480 0.096s 0.000s
# im_detect: 1461/1480 0.095s 0.000s
# im_detect: 1462/1480 0.093s 0.000s
# im_detect: 1463/1480 0.095s 0.000s
# im_detect: 1464/1480 0.098s 0.000s
# im_detect: 1465/1480 0.099s 0.000s
# im_detect: 1466/1480 0.096s 0.000s
# im_detect: 1467/1480 0.098s 0.000s
# im_detect: 1468/1480 0.094s 0.000s
# im_detect: 1469/1480 0.098s 0.000s
# im_detect: 1470/1480 0.097s 0.000s
# im_detect: 1471/1480 0.100s 0.000s
# im_detect: 1472/1480 0.097s 0.000s
# im_detect: 1473/1480 0.091s 0.000s
# im_detect: 1474/1480 0.092s 0.000s
# im_detect: 1475/1480 0.094s 0.000s
# im_detect: 1476/1480 0.096s 0.000s
# im_detect: 1477/1480 0.101s 0.000s
# im_detect: 1478/1480 0.092s 0.000s
# im_detect: 1479/1480 0.095s 0.000s
# im_detect: 1480/1480 0.096s 0.000s

# %%
pose_errors_all = np.array(pose_errors_all)
print pose_errors_all.shape
print np.mean(pose_errors_all, axis=0)
# Out:
# (3405, 7)
# [0.06627725 0.1128249  0.15780121 0.49880798 0.11826725 0.2224815
#  0.41734781]

# %%
print np.var(pose_errors_all, axis=0)
# Out:
# [0.00442502 0.02575688 0.04203296 0.42294348 0.06094262 0.07978684
#  0.25655702]
