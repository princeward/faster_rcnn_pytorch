# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
log_dir = "models/saved_model8"
rpn_ce = np.loadtxt(log_dir+"/loss_rpn_ce.txt")
rpn_box = np.loadtxt(log_dir+"/loss_rpn_box.txt")
rcnn_ce = np.loadtxt(log_dir+"/loss_rcnn_ce.txt")
rcnn_box = np.loadtxt(log_dir+"/loss_rcnn_box.txt")

# %%
plt.plot(rpn_ce)

# %%
plt.plot(rpn_box)

# %%
plt.plot(rcnn_ce)

# %%
plt.plot(rcnn_box)
plt.axis([0,rcnn_box.shape[0], 0, 0.3])
# Out:
# [0, 100001, 0, 0.3]
